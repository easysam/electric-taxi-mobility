# %%
import pandas as pd
import dask.dataframe as dd
import numpy as np
from sklearn.metrics.pairwise import haversine_distances
from dask.diagnostics import ProgressBar

# %%
from tqdm import tqdm

# %%
trajectories = dd.read_parquet('data/trajectory/statuses_wo_charging_resting')
cs = pd.read_csv('data/charging_station/ChargeLocation201706_wgs84.csv')

# %%
cs_wg = pd.read_csv('data/charging_station/ChargeLocation201706', names=['idx', 'name', 'lng', 'lat', 'online', 'charger_num'])

# %%
def find_nearest_station(traj, cs_info=None):
    dis = haversine_distances(np.radians(traj), np.radians(cs_info))
    return dis.argmin(axis=1), dis.min(axis=1)
result = trajectories[['latitude', 'longitude']].map_partitions(find_nearest_station, cs_info=cs_wg[['lat', 'lng']], meta={0: int, 1: float})

with ProgressBar():
    # num_workers=7 is the best, whole distance calculation canbe done at about 25 min, 
    # and the memory is used appropriately
    nearest_info = result.compute(scheduler='processes', num_workers=7)
# Out:
# [########################################] | 100% Completed | 16min 23.8s

# %%
df = pd.DataFrame(nearest_info.tolist(), index=nearest_info.index, columns=['s_idx', 's_dis'])
s_idx = [element for list_ in tqdm(df['s_idx'].values) for element in list_]
s_dis = [element for list_ in tqdm(df['s_dis'].values) for element in list_]
# Out:
# 100%|██████████| 21/21 [01:25<00:00,  4.05s/it]
# 100%|██████████| 21/21 [01:26<00:00,  4.13s/it]

# %%
traj = pd.read_parquet('data/trajectory/statuses_wo_charging_resting')
traj['s_idx'], traj['s_dis'] = pd.Series(s_idx), pd.Series(s_dis) * 6371008.8
traj.to_parquet('data/trajectory/trajectories_w_statuses_wgcs')

# %%
traj.iloc[100:150]
# Out:
#      license   longitude   latitude           timestamp  speed  occupied  \
# 100  粤B001ZD  113.881500  22.584299 2017-06-01 06:18:09     11     False
# 101  粤B001ZD  113.883797  22.581699 2017-06-01 06:18:59     19     False
# 102  粤B001ZD  113.881798  22.577499 2017-06-01 06:19:50     33     False
# 103  粤B001ZD  113.878601  22.574699 2017-06-01 06:20:40      0     False
# 104  粤B001ZD  113.878601  22.574699 2017-06-01 06:20:40      0     False
# 105  粤B001ZD  113.876602  22.572901 2017-06-01 06:21:30     23     False
# 106  粤B001ZD  113.871498  22.574800 2017-06-01 06:22:20     11     False
# 107  粤B001ZD  113.869102  22.576099 2017-06-01 06:23:10      0     False
# 108  粤B001ZD  113.871803  22.573999 2017-06-01 06:23:59      0     False
# 109  粤B001ZD  113.871803  22.573999 2017-06-01 06:24:50      0     False
# 110  粤B001ZD  113.874802  22.571800 2017-06-01 06:25:40      7     False
# 111  粤B001ZD  113.870796  22.568199 2017-06-01 06:26:30     16     False
# 112  粤B001ZD  113.867500  22.570601 2017-06-01 06:27:20     14     False
# 113  粤B001ZD  113.865898  22.571899 2017-06-01 06:28:10     13     False
# 114  粤B001ZD  113.868797  22.576200 2017-06-01 06:28:59     12     False
# 115  粤B001ZD  113.865997  22.578699 2017-06-01 06:29:51     14     False
# 116  粤B001ZD  113.863899  22.580601 2017-06-01 06:30:41      0     False
# 107             False  0.285279     50.0    False   True   True     19
# 108              True  0.362541     49.0    False   True   True     19
# 109              True  0.000000     51.0    False   True   True     19
# 110              True  0.393203     50.0    False   True  False     49
# 111              True  0.574042     50.0    False   True  False     49
# 112              True  0.431130     50.0    False   True  False     19
# 113              True  0.218834     50.0    False   True  False     19
# 114             False  0.563314     49.0    False   True  False     19
# 115             False  0.399829     52.0    False   True  False     19
# 116             False  0.301875     50.0    False   True   True     19
# 117             False  0.000000     50.0    False   True   True     19
# 118             False  0.000000      0.0    False   True   True     19
# 119             False  1.752783    100.0    False   True  False     19
# 120             False  0.000000      0.0    False   True  False     19
# 121             False  1.081860     50.0    False   True  False     23
# 122              True  0.986044    100.0    False   True  False     23
# 123              True  0.014982     50.0    False   True   True     23
# 124              True  0.489832     50.0    False   True  False     23
# 125              True  1.123525    100.0    False   True  False     23
# 126              True  0.914845     50.0    False   True  False     26
# 127              True  0.628187     50.0    False   True  False     26
# 128              True  0.000000      0.0    False   True  False     26
# 129              True  0.978057     50.0    False   True  False     26
# 130              True  0.000000      0.0    False   True  False     26
# 131              True  0.611351     50.0    False   True  False     26
# 132              True  0.305055     50.0    False   True  False     26
# 133              True  0.172787     50.0    False   True   True     26
# 134              True  0.116585     50.0    False   True  False     26
# 135              True  0.000000      0.0    False   True  False     26
# 136              True  0.622560     51.0    False   True  False     26
# 137              True  0.948604     49.0    False   True  False     26
# 138              True  0.638425     50.0    False   True  False     26
# 139             False  0.626963     50.0    False   True  False     26
# 140             False  0.703786     50.0    False   True  False     23
# 141             False  6.588551   1051.0    False   True  False     49
# 142             False  0.362567     50.0    False   True  False     49
# 143             False  0.563167     50.0    False   True  False     49
# 144             False  0.302712     49.0    False   True  False     49
# 145             False  0.234038     50.0    False   True  False     49
# 146             False  0.363209     52.0    False   True  False     49
# 147             False  0.650940     50.0    False   True  False     49
# 148             False  0.532738     50.0    False   True  False     49
# 149             False  0.000000      0.0    False   True  False     49
#
#            s_dis
# 100  2301.518022
# 101  2027.460056
# 102  1545.972807
# 103  1267.034315
# 104  1267.034315
# 105  1145.503660
# 106  1442.231306
# 107  1161.540084
# 108  1504.733652
# 109  1504.733652
# 110  1136.062100
# 111  1202.918684
# 112  1358.007312
# 113  1140.534276
# 114  1128.056247
# 115   785.333317
# 116   579.625705
# 117   579.625705
# 118   579.625705
# 119  1469.061968
# 120  1469.061968
# 121  1377.414171
# 122   398.245306
# 123   383.138956
# 124   137.882519
# 125  1205.926890
# 126  1497.752167
# 127  1248.030974
# 128  1248.030974
# 129   352.122963
# 130   352.122963
# 131   299.720318
# 132   536.004847
# 133   624.608818
# 134   699.744223
# 135   699.744223
# 136   636.111843
# 137  1236.470171
# 138  1637.499182
# 139  1507.986899
# 140  1264.549024
# 141  1816.679845
# 142  1545.567679
# 143  1174.996026
# 144   906.462515
# 145  1102.024216
# 146  1118.233866
# 147  1192.788457
# 148  1457.685632
# 149  1457.685632
